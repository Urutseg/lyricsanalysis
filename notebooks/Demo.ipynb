# %%
from src.lc import LyricsCharter
# Out:
# f:\python\python36\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
path_to_file = "data\jsons\madonna.json"

# %%
madonna = LyricsCharter(path_to_file, "Madonna")

# %%
madonna.songs_by_decade()

# %%
madonna.word_counts_density()
# Out:
# f:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
madonna.word_counts_trend()

# %%
madonna.word_counts_vs_unique()
# Out:
# f:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
madonna.top_n_words_heatmap()
